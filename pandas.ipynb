# %%
import pandas as  pd

# %%
number = pd.Series([10,20],index = ["ek","dui"])
print(number["dui"])
# Out:
# 20

# %%
countries =  pd.Series(["nepal","india","china"])
print(countries)
# Out:
# 0    nepal
# 1    india
# 2    china
# dtype: str

# %%
Student_data = {
    "name":["sonam","sonu","bikash"],
    "age":[10,20,30],
    "home":["sindhuwa","dharan","itahari"]
}
data = pd.DataFrame(Student_data)
print(data)
# Out:
#      name  age      home
# 0   sonam   10  sindhuwa
# 1    sonu   20    dharan
# 2  bikash   30   itahari

# %%
student_data = pd.read_csv("datasets/student_data.csv")

# %%
todos = pd.read_json("datasets/todos.json")

# %%
nd = pd.read_csv("datasets/netflix_dataset.csv")
# print(nd.head(2)) first 2 data
# print(nd.tail(5)) last 5 data
# print(nd.shape) gives info in tuple format showing no of row and cols
# print(nd.columns) gives info on colunms
# print(nd.info()) gives overall info on the dataset
# print(nd.describe()) gives numerical info on the columns 
# print(nd.sample()) gives random info of the dataset
