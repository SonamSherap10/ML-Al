# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# index  = [1,2,3,4]  #x axis
# price = [1000,2000,300,4000] #y axis
# plt.figure(figsize=(6,7))
# plt.plot(index,price)

# %%
dd = pd.read_csv("datasets/daraz_dataset.csv")

#BAR CHART
# # for category,data in dd.groupby("Category") :
# #  print(category)
# category=dd.groupby("Category")["Product"].count()
# # category.index   #category names = x label
# # category.values  # product count = y label
plt.figure(figsize=(10,4))
plt.bar(category.index,category.values,color="green",edgecolor="black")
plt.title("Products and category bar graph",fontsize=13)
plt.xlabel("categories",fontsize=15)
plt.ylabel("products",fontsize=15)
plt.grid(axis="y",linestyle="--")

# %%
#PIE CHART
category=dd.groupby("Category")["Product"].count()
plt.title("Product distribution by category")
plt.pie(category.values,labels=category.index,startangle=90,shadow=True,explode=(0,0,0,0,0.1,0,0))

# %%
# gender = dd.groupby("Gender")["Product"].count()
# plt.pie(gender.values,labels=gender.index,colors=["pink","green"])
# plt.title("products by gender")

# %%
#HISTOGRAM
# bins=[0,5000,10000,15000,20000,25000,30000,35000,40000,50000]
plt.hist(dd["UnitPrice"],bins=12, edgecolor="black")
plt.title("Distribution of unit price")
plt.xlabel("Frequency")
plt.ylabel("Unit Price")
# Out:
# Text(0, 0.5, 'Unit Price')

# %%
#SCATTER PLOT
# data= {
#     "Age" : [20,22,24,26,28,30],
#     "TotalAmount":[10000,12000,15000,18000,20000,25000]
# }

# df=pd.DataFrame(data)
# plt.scatter(df["Age"],df["TotalAmount"])
# plt.xlabel("Age",fontsize=12)
# plt.ylabel("Total Amount",fontsize= 12)
# plt.title("Total Amount vs Age",fontsize=15)
# plt.figure(figsize=(10,10))
plt.scatter(dd["Age"],dd["TotalAmount"],color="green",s=80)
plt.title("Age vs TotalAmount")
plt.xlabel("Age")
plt.ylabel("Total Amount")
plt.grid(True)

# %%
#BOX PLOT
plt.boxplot(dd["TotalAmount"])
plt.title("Box Plot of Total Amount")
plt.ylabel("Unit Price")
# Out:
# Text(0, 0.5, 'Unit Price')
