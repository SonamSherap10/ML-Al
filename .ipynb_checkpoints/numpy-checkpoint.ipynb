# %%
import numpy as np
import pandas as pd

# %%
# data = np.array([[10,100],
#              [20,200],
#              [30,300]])
# print(data.ndim)
# print(data.shape)
# print(data[1:])
# print(data.reshape(-1))

# %%
df = pd.read_csv("datasets/daraz_dataset.csv")

# %%
numeric_columns=["Age","Quantity","UnitPrice","DiscountPercent","TotalAmount","Rating"]
for columns in numeric_columns:
  df[columns]=pd.to_numeric(df[columns],errors="coerce")
df["DiscountPercent"]=df["DiscountPercent"].fillna(df["DiscountPercent"].mean())
features=['Age', 'Quantity', 'UnitPrice', 'DiscountPercent']
target= "TotalAmount"

X = df[features]
y = df[target]

X=X.to_numpy()
y=y.to_numpy()

# X.nbytes shows how much memory is being used
X
# Out:
# array([[3.20000000e+01,            nan,            nan, 1.06312625e+01],
#        [5.20000000e+01, 2.00000000e+00, 3.34180000e+04, 2.00000000e+01],
#        [3.10000000e+01, 2.00000000e+00, 4.60530000e+04, 1.50000000e+01],
#        ...,
#        [2.70000000e+01, 1.00000000e+00, 4.88900000e+04, 0.00000000e+00],
#        [2.70000000e+01, 5.00000000e+00, 2.46800000e+03, 1.00000000e+01],
#        [2.50000000e+01, 2.00000000e+00, 3.81630000e+04, 1.00000000e+01]],
#       shape=(500, 4))

# %%
student_data= np.array([
    [12,50],
    [14,60],
    [16,80]
])
weights= np.array([
    [10],
    [2]])

prediction = np.dot(student_data,weights)
print(prediction)
# Out:
# [[220]
#  [260]
#  [320]]
